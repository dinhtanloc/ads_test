# %%
import numpy as np 
import math
import pandas as pd
import random as rd
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler

# %%
exps_dir = "../../exps"
if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
x_train
# Out:
#       months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                      2    0             0           1                  1
# 1                      0    2             1           0                  2
# 2                      2    0             2           0                  2
# 3                      2    0             0           0                  2
# 4                      2    0             2           1                  1
# ...                  ...  ...           ...         ...                ...
# 1017                   2    0             2           0                  2
# 1018                   1    0             0           0                  0
# 1019                   0    0             1           0                  1
# 1020                   0    0             1           0                  0
# 1021                   1    0             0           1                  0
#
#       policy_annual_premium  umbrella_limit  insured_sex  \
# 0                 -1.770734               0            1
# 1                 -1.979562               0            1
# 2                  0.675544               0            0
# 3                 -0.492901               0            0
# 4                  0.613672               0            1
# ...                     ...             ...          ...
# 1017              -1.393488               0            0
# 1018               0.661055               0            0
# 1019              -0.077354               5            1
# 1020              -0.839075               3            0
# 1021              -0.070194               0            1
#
#       insured_education_level  insured_occupation  ...  auto_year  \
# 0                           2                  11  ...          2
# 1                           4                  11  ...          0
# 2                           0                   5  ...          1
# 3                           2                   2  ...          0
# 4                           4                   2  ...          1
# ...                       ...                 ...  ...        ...
# 1017                        0                   6  ...          1
# 1018                        1                   3  ...          0
# 1019                        4                   3  ...          1
# 1020                        5                   5  ...          1
# 1021                        3                   3  ...          0
#
#       day_policy_bind_date  month_policy_bind_date  year_policy_bind_date  \
# 0                 0.579574               -0.179439              -1.020460
# 1                -0.547936               -0.179439               0.908584
# 2                 1.481582                0.108179              -0.744883
# 3                 1.368831               -0.467057               1.735317
# 4                 0.128570                0.971032               1.735317
# ...                    ...                     ...                    ...
# 1017              0.908354                0.656524               0.393463
# 1018              0.839585               -0.592273               1.479683
# 1019             -0.883912               -0.196871              -1.006542
# 1020              0.355841               -0.752419               0.704873
# 1021              0.917317               -0.750775               1.459428
#
#       day_incident_date  month_incident_date  year_incident_date  \
# 0             -1.393943            -0.947412                   0
# 1              0.115223             0.953085                   0
# 2              0.115223            -0.947412                   0
# 3             -1.626123             2.853582                   0
# 4              1.160031            -0.947412                   0
# ...                 ...                  ...                 ...
# 1017          -0.917630            -0.947412                   0
# 1018           0.680663             0.953085                   0
# 1019          -0.093503             0.914690                   0
# 1020           0.118865             0.953085                   0
# 1021          -0.233308            -0.947412                   0
#
#       week_incident_date  high_week  high_hour
# 0              -1.705084          0          0
# 1               1.136723          0          0
# 2              -0.893139          1          0
# 3               1.542695          0          0
# 4              -0.487167          1          0
# ...                  ...        ...        ...
# 1017           -1.409131          0          0
# 1018            1.071228          0          0
# 1019            0.706145          1          1
# 1020            0.936124          0          0
# 1021           -0.893139          1          0
#
# [1022 rows x 42 columns]

# %%
# -*- coding: utf-8 -*-
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input

def VGG19():
    # Determine proper input shape
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    # Block 1
    x = Conv1D(64, 3, activation='relu', padding='same', name='block1_conv1')(x_input)
    x = Conv1D(64, 3, activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling1D(2, strides=2, name='block1_pool')(x)

    # Block 2
    x = Conv1D(128, 3, activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv1D(128, 3, activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling1D(2, strides=2, name='block2_pool')(x)

    # Block 3
    x = Conv1D(256, 3, activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv1D(256, 3, activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv1D(256, 3, activation='relu', padding='same', name='block3_conv3')(x)
    x = Conv1D(256, 3, activation='relu', padding='same', name='block3_conv4')(x)
    x = MaxPooling1D(2, strides=2, name='block3_pool')(x)

    # Block 4
    x = Conv1D(512, 3, activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block4_conv3')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block4_conv4')(x)
    x = MaxPooling1D(2, strides=2, name='block4_pool')(x)

    # Block 5
    x = Conv1D(512, 3, activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block5_conv3')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block5_conv4')(x)

    x = MaxPooling1D(2, strides=2, name='block5_pool')(x)
    
    x = Flatten(name='flatten')(x)
    x = Dense(4096, activation='relu', name='fc1')(x)
    x = Dense(4096, activation='relu', name='fc2')(x)
    x = Dense(1, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

    #x = GlobalAveragePooling1D()(x)
    #x = GlobalMaxPooling1D()(x)
    #x = Dense(classes, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

    # Create model.
    model = Model(x_input, x, name='vgg16')
    return model
model = VGG19()
lr=0.0001
model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 42, 64)            256
#
#  block1_conv2 (Conv1D)       (None, 42, 64)            12352
#
#  block1_pool (MaxPooling1D)  (None, 21, 64)            0
#
#  block2_conv1 (Conv1D)       (None, 21, 128)           24704
#
#  block2_conv2 (Conv1D)       (None, 21, 128)           49280
#
#  block2_pool (MaxPooling1D)  (None, 10, 128)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 256)           98560
#
#  block3_conv2 (Conv1D)       (None, 10, 256)           196864
#
#  block3_conv3 (Conv1D)       (None, 10, 256)           196864
#
#  block3_conv4 (Conv1D)       (None, 10, 256)           196864
#
#  block3_pool (MaxPooling1D)  (None, 5, 256)            0
#
#  block4_conv1 (Conv1D)       (None, 5, 512)            393728
#
#  block4_conv2 (Conv1D)       (None, 5, 512)            786944
#
#  block4_conv3 (Conv1D)       (None, 5, 512)            786944
#
#  block4_conv4 (Conv1D)       (None, 5, 512)            786944
#
#  block4_pool (MaxPooling1D)  (None, 2, 512)            0
#
#  block5_conv1 (Conv1D)       (None, 2, 512)            786944
#
#  block5_conv2 (Conv1D)       (None, 2, 512)            786944
#
#  block5_conv3 (Conv1D)       (None, 2, 512)            786944
#
#  block5_conv4 (Conv1D)       (None, 2, 512)            786944
#
#  block5_pool (MaxPooling1D)  (None, 1, 512)            0
#
#  flatten (Flatten)           (None, 512)               0
#
#  fc1 (Dense)                 (None, 4096)              2101248
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1)                 4097
#
# =================================================================
# Total params: 25,564,737
# Trainable params: 25,564,737
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\PC\miniconda3\envs\test\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
earlystopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 30)

early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=11,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=30,
    min_lr=0.000001,
    verbose=1,
)
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import confusion_matrix

class ConfusionMatrixCallback(Callback):
    def __init__(self, validation_data):
        self.validation_data = validation_data
        self.relist={}
        self.acc=[]

    def on_epoch_end(self, epoch, logs=None):
        X_val, y_val = self.validation_data
        y_pred = self.model.predict(X_val)
        y_pred_binary = (y_pred > 0.5).astype(int)

        cm = confusion_matrix(y_val, y_pred_binary)
        print(f"Confusion Matrix after Epoch {epoch + 1}:\n{cm}")
        print(classification_report(y_test,y_pred_binary))
        acc = float(classification_report(y_test,y_pred_binary).split('\n')[3].split()[2])
        self.acc.append(acc)
        self.relist[acc]=y_pred_binary

# ... Định nghĩa mô hình ...

# Tạo đối tượng callback
confusion_matrix_callback = ConfusionMatrixCallback(validation_data=(x_test,y_test))

callbacks = [early_stopping,lr_scheduler]

checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5", verbose = 1, save_best_only=True)

history=model.fit(x=x_train,y=y_train,
          validation_data=(x_test,y_test),
          batch_size=64,epochs=120, callbacks=[earlystopping,checkpointer])
# Out:
# Epoch 1/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6950 - accuracy: 0.4883
# Epoch 1: val_loss improved from inf to 0.68822, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 5s 219ms/step - loss: 0.6950 - accuracy: 0.4883 - val_loss: 0.6882 - val_accuracy: 0.7333
# Epoch 2/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6930 - accuracy: 0.5382
# Epoch 2: val_loss did not improve from 0.68822
# 16/16 [==============================] - 2s 137ms/step - loss: 0.6930 - accuracy: 0.5382 - val_loss: 0.6933 - val_accuracy: 0.3879
# Epoch 3/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6926 - accuracy: 0.5822
# Epoch 3: val_loss improved from 0.68822 to 0.68725, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 3s 180ms/step - loss: 0.6926 - accuracy: 0.5822 - val_loss: 0.6873 - val_accuracy: 0.7364
# Epoch 4/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6843 - accuracy: 0.5284
# Epoch 4: val_loss improved from 0.68725 to 0.60112, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 3s 197ms/step - loss: 0.6843 - accuracy: 0.5284 - val_loss: 0.6011 - val_accuracy: 0.7242
# Epoch 5/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.4980
# Epoch 5: val_loss did not improve from 0.60112
# 16/16 [==============================] - 2s 134ms/step - loss: 0.6925 - accuracy: 0.4980 - val_loss: 0.7051 - val_accuracy: 0.2667
# Epoch 6/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.4980
# Epoch 6: val_loss did not improve from 0.60112
# 16/16 [==============================] - 2s 132ms/step - loss: 0.6936 - accuracy: 0.4980 - val_loss: 0.6943 - val_accuracy: 0.3030
# Epoch 7/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5108
# Epoch 7: val_loss did not improve from 0.60112
# 16/16 [==============================] - 2s 129ms/step - loss: 0.6931 - accuracy: 0.5108 - val_loss: 0.6946 - val_accuracy: 0.3606
# Epoch 8/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6928 - accuracy: 0.5137
# Epoch 8: val_loss did not improve from 0.60112
# 16/16 [==============================] - 2s 130ms/step - loss: 0.6928 - accuracy: 0.5137 - val_loss: 0.6748 - val_accuracy: 0.7333
# Epoch 9/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6923 - accuracy: 0.5068
# Epoch 9: val_loss did not improve from 0.60112
# 16/16 [==============================] - 2s 131ms/step - loss: 0.6923 - accuracy: 0.5068 - val_loss: 0.6900 - val_accuracy: 0.6152
# Epoch 10/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6837 - accuracy: 0.6027
# Epoch 10: val_loss did not improve from 0.60112
# 16/16 [==============================] - 2s 136ms/step - loss: 0.6837 - accuracy: 0.6027 - val_loss: 0.6634 - val_accuracy: 0.6212
# Epoch 11/120
# 16/16 [==============================] - ETA: 0s - loss: 0.6461 - accuracy: 0.6536
# Epoch 11: val_loss improved from 0.60112 to 0.59747, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 3s 179ms/step - loss: 0.6461 - accuracy: 0.6536 - val_loss: 0.5975 - val_accuracy: 0.6879
# Epoch 12/120
# 16/16 [==============================] - ETA: 0s - loss: 0.5623 - accuracy: 0.7348
# Epoch 12: val_loss improved from 0.59747 to 0.59084, saving model to Emotion_weights.hdf5
# 16/16 [==============================] - 3s 171ms/step - loss: 0.5623 - accuracy: 0.7348 - val_loss: 0.5908 - val_accuracy: 0.7182
# Epoch 13/120
# 16/16 [==============================] - ETA: 0s - loss: 0.5253 - accuracy: 0.7495
# Epoch 13: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 128ms/step - loss: 0.5253 - accuracy: 0.7495 - val_loss: 0.6215 - val_accuracy: 0.7061
# Epoch 14/120
# 16/16 [==============================] - ETA: 0s - loss: 0.4216 - accuracy: 0.8288
# Epoch 14: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 133ms/step - loss: 0.4216 - accuracy: 0.8288 - val_loss: 0.6920 - val_accuracy: 0.7212
# Epoch 15/120
# 16/16 [==============================] - ETA: 0s - loss: 0.4272 - accuracy: 0.8170
# Epoch 15: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 128ms/step - loss: 0.4272 - accuracy: 0.8170 - val_loss: 0.6154 - val_accuracy: 0.7273
# Epoch 16/120
# 16/16 [==============================] - ETA: 0s - loss: 0.3808 - accuracy: 0.8327
# Epoch 16: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 134ms/step - loss: 0.3808 - accuracy: 0.8327 - val_loss: 0.6425 - val_accuracy: 0.7182
# Epoch 17/120
# 16/16 [==============================] - ETA: 0s - loss: 0.2943 - accuracy: 0.8904
# Epoch 17: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 127ms/step - loss: 0.2943 - accuracy: 0.8904 - val_loss: 0.8133 - val_accuracy: 0.7000
# Epoch 18/120
# 16/16 [==============================] - ETA: 0s - loss: 0.2448 - accuracy: 0.9090
# Epoch 18: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 131ms/step - loss: 0.2448 - accuracy: 0.9090 - val_loss: 0.8262 - val_accuracy: 0.6818
# Epoch 19/120
# 16/16 [==============================] - ETA: 0s - loss: 0.2264 - accuracy: 0.9139
# Epoch 19: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 131ms/step - loss: 0.2264 - accuracy: 0.9139 - val_loss: 0.8851 - val_accuracy: 0.6879
# Epoch 20/120
# 16/16 [==============================] - ETA: 0s - loss: 0.1636 - accuracy: 0.9432
# Epoch 20: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 133ms/step - loss: 0.1636 - accuracy: 0.9432 - val_loss: 1.0977 - val_accuracy: 0.7242
# Epoch 21/120
# 16/16 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9472
# Epoch 21: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 135ms/step - loss: 0.1340 - accuracy: 0.9472 - val_loss: 1.1702 - val_accuracy: 0.7121
# Epoch 22/120
# 16/16 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9315
# Epoch 22: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 138ms/step - loss: 0.1758 - accuracy: 0.9315 - val_loss: 0.7519 - val_accuracy: 0.7000
# Epoch 23/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0632 - accuracy: 0.9834
# Epoch 23: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 139ms/step - loss: 0.0632 - accuracy: 0.9834 - val_loss: 1.5451 - val_accuracy: 0.6970
# Epoch 24/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9726
# Epoch 24: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 140ms/step - loss: 0.0896 - accuracy: 0.9726 - val_loss: 1.4297 - val_accuracy: 0.7152
# Epoch 25/120
# 16/16 [==============================] - ETA: 0s - loss: 0.1350 - accuracy: 0.9413
# Epoch 25: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 133ms/step - loss: 0.1350 - accuracy: 0.9413 - val_loss: 0.9828 - val_accuracy: 0.6636
# Epoch 26/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9687
# Epoch 26: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 129ms/step - loss: 0.0821 - accuracy: 0.9687 - val_loss: 1.3448 - val_accuracy: 0.6909
# Epoch 27/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9902
# Epoch 27: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 138ms/step - loss: 0.0309 - accuracy: 0.9902 - val_loss: 1.7791 - val_accuracy: 0.6939
# Epoch 28/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9814
# Epoch 28: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 130ms/step - loss: 0.0546 - accuracy: 0.9814 - val_loss: 1.5484 - val_accuracy: 0.7061
# Epoch 29/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9922
# Epoch 29: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 135ms/step - loss: 0.0226 - accuracy: 0.9922 - val_loss: 1.5629 - val_accuracy: 0.7000
# Epoch 30/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9932
# Epoch 30: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 133ms/step - loss: 0.0148 - accuracy: 0.9932 - val_loss: 1.9145 - val_accuracy: 0.6939
# Epoch 31/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9951
# Epoch 31: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 141ms/step - loss: 0.0131 - accuracy: 0.9951 - val_loss: 2.4624 - val_accuracy: 0.7121
# Epoch 32/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9863
# Epoch 32: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 141ms/step - loss: 0.0442 - accuracy: 0.9863 - val_loss: 1.8454 - val_accuracy: 0.7121
# Epoch 33/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9824
# Epoch 33: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0456 - accuracy: 0.9824 - val_loss: 1.3244 - val_accuracy: 0.6848
# Epoch 34/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9843
# Epoch 34: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 145ms/step - loss: 0.0431 - accuracy: 0.9843 - val_loss: 1.7173 - val_accuracy: 0.7152
# Epoch 35/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9824
# Epoch 35: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 144ms/step - loss: 0.0544 - accuracy: 0.9824 - val_loss: 1.2619 - val_accuracy: 0.6788
# Epoch 36/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9951
# Epoch 36: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 139ms/step - loss: 0.0183 - accuracy: 0.9951 - val_loss: 1.9696 - val_accuracy: 0.7000
# Epoch 37/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9971
# Epoch 37: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 157ms/step - loss: 0.0073 - accuracy: 0.9971 - val_loss: 2.5419 - val_accuracy: 0.7121
# Epoch 38/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9912
# Epoch 38: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 136ms/step - loss: 0.0252 - accuracy: 0.9912 - val_loss: 2.3665 - val_accuracy: 0.6727
# Epoch 39/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9912
# Epoch 39: val_loss did not improve from 0.59084
# 16/16 [==============================] - 3s 185ms/step - loss: 0.0271 - accuracy: 0.9912 - val_loss: 1.7417 - val_accuracy: 0.7273
# Epoch 40/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9922
# Epoch 40: val_loss did not improve from 0.59084
# 16/16 [==============================] - 3s 194ms/step - loss: 0.0231 - accuracy: 0.9922 - val_loss: 1.7977 - val_accuracy: 0.7061
# Epoch 41/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9961
# Epoch 41: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0171 - accuracy: 0.9961 - val_loss: 1.8762 - val_accuracy: 0.6758
# Epoch 42/120
# 16/16 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9971
# Epoch 42: val_loss did not improve from 0.59084
# 16/16 [==============================] - 2s 145ms/step - loss: 0.0104 - accuracy: 0.9971 - val_loss: 2.4040 - val_accuracy: 0.6576
# Epoch 42: early stopping

# %%
losses = pd.DataFrame(history.history)
losses.plot()
# Out:
# <Axes: >

# %%
y_pred = model.predict(x_test)
y_pred_binary = (y_pred > 0.5).astype(int)
print(classification_report(y_test,y_pred_binary))
# Out:
# 11/11 [==============================] - 0s 26ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.67      0.74       242
#            1       0.41      0.62      0.49        88
#
#     accuracy                           0.66       330
#    macro avg       0.62      0.65      0.62       330
# weighted avg       0.72      0.66      0.68       330
