# %%
import numpy as np 
import math
import pandas as pd
import random as rd
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler

# %%
exps_dir = "../../exps"
if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/feature1"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
x_train
# Out:
#       months_as_customer  age  policy_state  policy_csl  policy_deductable  \
# 0                      2    0             0           1                  1
# 1                      0    2             1           0                  2
# 2                      2    0             2           0                  2
# 3                      2    0             0           0                  2
# 4                      2    0             2           1                  1
# ...                  ...  ...           ...         ...                ...
# 1017                   2    0             2           0                  2
# 1018                   1    0             0           0                  0
# 1019                   0    0             1           0                  1
# 1020                   0    0             1           0                  0
# 1021                   1    0             0           1                  0
#
#       policy_annual_premium  umbrella_limit  insured_sex  \
# 0                 -1.770734               0            1
# 1                 -1.979562               0            1
# 2                  0.675544               0            0
# 3                 -0.492901               0            0
# 4                  0.613672               0            1
# ...                     ...             ...          ...
# 1017              -1.393488               0            0
# 1018               0.661055               0            0
# 1019              -0.077354               5            1
# 1020              -0.839075               3            0
# 1021              -0.070194               0            1
#
#       insured_education_level  insured_occupation  ...  auto_year  \
# 0                           2                  11  ...          2
# 1                           4                  11  ...          0
# 2                           0                   5  ...          1
# 3                           2                   2  ...          0
# 4                           4                   2  ...          1
# ...                       ...                 ...  ...        ...
# 1017                        0                   6  ...          1
# 1018                        1                   3  ...          0
# 1019                        4                   3  ...          1
# 1020                        5                   5  ...          1
# 1021                        3                   3  ...          0
#
#       day_policy_bind_date  month_policy_bind_date  year_policy_bind_date  \
# 0                 0.579574               -0.179439              -1.020460
# 1                -0.547936               -0.179439               0.908584
# 2                 1.481582                0.108179              -0.744883
# 3                 1.368831               -0.467057               1.735317
# 4                 0.128570                0.971032               1.735317
# ...                    ...                     ...                    ...
# 1017              0.908354                0.656524               0.393463
# 1018              0.839585               -0.592273               1.479683
# 1019             -0.883912               -0.196871              -1.006542
# 1020              0.355841               -0.752419               0.704873
# 1021              0.917317               -0.750775               1.459428
#
#       day_incident_date  month_incident_date  year_incident_date  \
# 0             -1.393943            -0.947412                   0
# 1              0.115223             0.953085                   0
# 2              0.115223            -0.947412                   0
# 3             -1.626123             2.853582                   0
# 4              1.160031            -0.947412                   0
# ...                 ...                  ...                 ...
# 1017          -0.917630            -0.947412                   0
# 1018           0.680663             0.953085                   0
# 1019          -0.093503             0.914690                   0
# 1020           0.118865             0.953085                   0
# 1021          -0.233308            -0.947412                   0
#
#       week_incident_date  high_week  high_hour
# 0              -1.705084          0          0
# 1               1.136723          0          0
# 2              -0.893139          1          0
# 3               1.542695          0          0
# 4              -0.487167          1          0
# ...                  ...        ...        ...
# 1017           -1.409131          0          0
# 1018            1.071228          0          0
# 1019            0.706145          1          1
# 1020            0.936124          0          0
# 1021           -0.893139          1          0
#
# [1022 rows x 42 columns]

# %%
# -*- coding: utf-8 -*-
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Dense, Flatten
from keras.models import Model
from keras.layers import Input

def VGG19():
    # Determine proper input shape
    input_shape =(42,1)
    x_input = Input(shape=input_shape)

    # Block 1
    x = Conv1D(64, 3, activation='relu', padding='same', name='block1_conv1')(x_input)
    x = Conv1D(64, 3, activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling1D(2, strides=2, name='block1_pool')(x)

    # Block 2
    x = Conv1D(128, 3, activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv1D(128, 3, activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling1D(2, strides=2, name='block2_pool')(x)

    # Block 3
    x = Conv1D(256, 3, activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv1D(256, 3, activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv1D(256, 3, activation='relu', padding='same', name='block3_conv3')(x)
    x = Conv1D(256, 3, activation='relu', padding='same', name='block3_conv4')(x)
    x = MaxPooling1D(2, strides=2, name='block3_pool')(x)

    # Block 4
    x = Conv1D(512, 3, activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block4_conv3')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block4_conv4')(x)
    x = MaxPooling1D(2, strides=2, name='block4_pool')(x)

    # Block 5
    x = Conv1D(512, 3, activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block5_conv3')(x)
    x = Conv1D(512, 3, activation='relu', padding='same', name='block5_conv4')(x)

    x = MaxPooling1D(2, strides=2, name='block5_pool')(x)
    
    x = Flatten(name='flatten')(x)
    x = Dense(4096, activation='relu', name='fc1')(x)
    x = Dense(4096, activation='relu', name='fc2')(x)
    x = Dense(1, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

    #x = GlobalAveragePooling1D()(x)
    #x = GlobalMaxPooling1D()(x)
    #x = Dense(classes, activation='sigmoid', name='predictions')(x)  # Sigmoid for binary classification

    # Create model.
    model = Model(x_input, x, name='vgg16')
    return model
model = VGG19()
lr=0.0001
model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])

# Summary of the model
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 42, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 42, 64)            256
#
#  block1_conv2 (Conv1D)       (None, 42, 64)            12352
#
#  block1_pool (MaxPooling1D)  (None, 21, 64)            0
#
#  block2_conv1 (Conv1D)       (None, 21, 128)           24704
#
#  block2_conv2 (Conv1D)       (None, 21, 128)           49280
#
#  block2_pool (MaxPooling1D)  (None, 10, 128)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 256)           98560
#
#  block3_conv2 (Conv1D)       (None, 10, 256)           196864
#
#  block3_conv3 (Conv1D)       (None, 10, 256)           196864
#
#  block3_conv4 (Conv1D)       (None, 10, 256)           196864
#
#  block3_pool (MaxPooling1D)  (None, 5, 256)            0
#
#  block4_conv1 (Conv1D)       (None, 5, 512)            393728
#
#  block4_conv2 (Conv1D)       (None, 5, 512)            786944
#
#  block4_conv3 (Conv1D)       (None, 5, 512)            786944
#
#  block4_conv4 (Conv1D)       (None, 5, 512)            786944
#
#  block4_pool (MaxPooling1D)  (None, 2, 512)            0
#
#  block5_conv1 (Conv1D)       (None, 2, 512)            786944
#
#  block5_conv2 (Conv1D)       (None, 2, 512)            786944
#
#  block5_conv3 (Conv1D)       (None, 2, 512)            786944
#
#  block5_conv4 (Conv1D)       (None, 2, 512)            786944
#
#  block5_pool (MaxPooling1D)  (None, 1, 512)            0
#
#  flatten (Flatten)           (None, 512)               0
#
#  fc1 (Dense)                 (None, 4096)              2101248
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1)                 4097
#
# =================================================================
# Total params: 25,564,737
# Trainable params: 25,564,737
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\PC\miniconda3\envs\test\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
earlystopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 30)

early_stopping = EarlyStopping(monitor='val_accuracy',
    min_delta=0.00005,
    patience=50,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
from tensorflow.keras.callbacks import Callback
from sklearn.metrics import confusion_matrix

class ConfusionMatrixCallback(Callback):
    def __init__(self, validation_data):
        self.validation_data = validation_data
        self.relist={}
        self.acc=[]

    def on_epoch_end(self, epoch, logs=None):
        X_val, y_val = self.validation_data
        y_pred = self.model.predict(X_val)
        y_pred_binary = (y_pred > 0.5).astype(int)

        cm = confusion_matrix(y_val, y_pred_binary)
        print(f"Confusion Matrix after Epoch {epoch + 1}:\n{cm}")
        print(classification_report(y_test,y_pred_binary))
        acc = float(classification_report(y_test,y_pred_binary).split('\n')[3].split()[2])
        self.acc.append(acc)
        self.relist[acc]=y_pred_binary

# ... Định nghĩa mô hình ...

# Tạo đối tượng callback
confusion_matrix_callback = ConfusionMatrixCallback(validation_data=(x_test,y_test))

callbacks = [early_stopping,lr_scheduler]

checkpointer = ModelCheckpoint(filepath = "Emotion_weights.hdf5", verbose = 1, save_best_only=True)

history=model.fit(x=x_train,y=y_train,
          validation_data=(x_test,y_test),
          batch_size=32,epochs=600, callbacks=[early_stopping,lr_scheduler])
# Out:
# Epoch 1/600
# 32/32 [==============================] - 5s 105ms/step - loss: 0.6933 - accuracy: 0.5010 - val_loss: 0.6901 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 2/600
# 32/32 [==============================] - 3s 89ms/step - loss: 0.6932 - accuracy: 0.5039 - val_loss: 0.6850 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 3/600
# 32/32 [==============================] - 3s 91ms/step - loss: 0.6936 - accuracy: 0.4726 - val_loss: 0.6931 - val_accuracy: 0.4909 - lr: 1.0000e-04
# Epoch 4/600
# 32/32 [==============================] - 3s 91ms/step - loss: 0.6902 - accuracy: 0.5157 - val_loss: 0.6280 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 5/600
# 32/32 [==============================] - 3s 88ms/step - loss: 0.6715 - accuracy: 0.5783 - val_loss: 0.6910 - val_accuracy: 0.5182 - lr: 1.0000e-04
# Epoch 6/600
# 32/32 [==============================] - 3s 88ms/step - loss: 0.6631 - accuracy: 0.6145 - val_loss: 0.5878 - val_accuracy: 0.6788 - lr: 1.0000e-04
# Epoch 7/600
# 32/32 [==============================] - 3s 88ms/step - loss: 0.5342 - accuracy: 0.7564 - val_loss: 0.6911 - val_accuracy: 0.6939 - lr: 1.0000e-04
# Epoch 8/600
# 32/32 [==============================] - 3s 90ms/step - loss: 0.4316 - accuracy: 0.8092 - val_loss: 0.6919 - val_accuracy: 0.7303 - lr: 1.0000e-04
# Epoch 9/600
# 32/32 [==============================] - 3s 92ms/step - loss: 0.4225 - accuracy: 0.8112 - val_loss: 0.5600 - val_accuracy: 0.7424 - lr: 1.0000e-04
# Epoch 10/600
# 32/32 [==============================] - 3s 87ms/step - loss: 0.3538 - accuracy: 0.8571 - val_loss: 0.6015 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 11/600
# 32/32 [==============================] - 3s 88ms/step - loss: 0.2714 - accuracy: 0.8855 - val_loss: 0.6704 - val_accuracy: 0.7303 - lr: 1.0000e-04
# Epoch 12/600
# 32/32 [==============================] - 3s 90ms/step - loss: 0.2590 - accuracy: 0.9090 - val_loss: 0.7204 - val_accuracy: 0.7242 - lr: 1.0000e-04
# Epoch 13/600
# 32/32 [==============================] - 3s 94ms/step - loss: 0.2601 - accuracy: 0.9002 - val_loss: 0.6137 - val_accuracy: 0.7303 - lr: 1.0000e-04
# Epoch 14/600
# 32/32 [==============================] - 3s 94ms/step - loss: 0.1864 - accuracy: 0.9315 - val_loss: 0.8744 - val_accuracy: 0.7303 - lr: 1.0000e-04
# Epoch 15/600
# 32/32 [==============================] - 3s 94ms/step - loss: 0.1370 - accuracy: 0.9530 - val_loss: 1.0492 - val_accuracy: 0.7152 - lr: 1.0000e-04
# Epoch 16/600
# 32/32 [==============================] - 3s 94ms/step - loss: 0.1396 - accuracy: 0.9481 - val_loss: 0.9664 - val_accuracy: 0.7242 - lr: 1.0000e-04
# Epoch 17/600
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0911 - accuracy: 0.9736 - val_loss: 1.1046 - val_accuracy: 0.7091 - lr: 1.0000e-04
# Epoch 18/600
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0850 - accuracy: 0.9726 - val_loss: 1.4709 - val_accuracy: 0.7424 - lr: 1.0000e-04
# Epoch 19/600
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0904 - accuracy: 0.9677 - val_loss: 1.1299 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 20/600
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0749 - accuracy: 0.9765 - val_loss: 1.1362 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 21/600
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0925 - accuracy: 0.9667 - val_loss: 1.0805 - val_accuracy: 0.7394 - lr: 1.0000e-04
# Epoch 22/600
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0468 - accuracy: 0.9853 - val_loss: 1.4044 - val_accuracy: 0.7424 - lr: 1.0000e-04
# Epoch 23/600
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0511 - accuracy: 0.9853 - val_loss: 1.7624 - val_accuracy: 0.7303 - lr: 1.0000e-04
# Epoch 24/600
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0746 - accuracy: 0.9746 - val_loss: 1.1949 - val_accuracy: 0.6939 - lr: 1.0000e-04
# Epoch 25/600
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0390 - accuracy: 0.9892 - val_loss: 1.8091 - val_accuracy: 0.7121 - lr: 1.0000e-04
# Epoch 26/600
# 32/32 [==============================] - 3s 94ms/step - loss: 0.0481 - accuracy: 0.9814 - val_loss: 1.5453 - val_accuracy: 0.7485 - lr: 1.0000e-04
# Epoch 27/600
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0264 - accuracy: 0.9912 - val_loss: 1.8270 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 28/600
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0376 - accuracy: 0.9873 - val_loss: 1.6894 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 29/600
# 32/32 [==============================] - 3s 90ms/step - loss: 0.0231 - accuracy: 0.9912 - val_loss: 2.0118 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 30/600
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0212 - accuracy: 0.9932 - val_loss: 1.3998 - val_accuracy: 0.7303 - lr: 1.0000e-04
# Epoch 31/600
# 32/32 [==============================] - 3s 93ms/step - loss: 0.0202 - accuracy: 0.9961 - val_loss: 2.4071 - val_accuracy: 0.7455 - lr: 1.0000e-04
# Epoch 32/600
# 32/32 [==============================] - 3s 91ms/step - loss: 0.0079 - accuracy: 0.9990 - val_loss: 2.1528 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 33/600
# 32/32 [==============================] - 3s 92ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 2.6013 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 34/600
# 32/32 [==============================] - 3s 93ms/step - loss: 1.7459e-04 - accuracy: 1.0000 - val_loss: 2.9045 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 35/600
# 32/32 [==============================] - 3s 94ms/step - loss: 6.5824e-05 - accuracy: 1.0000 - val_loss: 3.1781 - val_accuracy: 0.7242 - lr: 1.0000e-04
# Epoch 36/600
# 32/32 [==============================] - 3s 94ms/step - loss: 2.8542e-05 - accuracy: 1.0000 - val_loss: 3.4929 - val_accuracy: 0.7273 - lr: 1.0000e-04
# Epoch 37/600
# 32/32 [==============================] - 3s 94ms/step - loss: 1.1339e-05 - accuracy: 1.0000 - val_loss: 3.7169 - val_accuracy: 0.7303 - lr: 1.0000e-04
# Epoch 38/600
# 32/32 [==============================] - 3s 94ms/step - loss: 5.4206e-06 - accuracy: 1.0000 - val_loss: 3.9600 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 39/600
# 32/32 [==============================] - 3s 92ms/step - loss: 2.9645e-06 - accuracy: 1.0000 - val_loss: 4.1324 - val_accuracy: 0.7364 - lr: 1.0000e-04
# Epoch 40/600
# 32/32 [==============================] - 3s 94ms/step - loss: 1.9046e-06 - accuracy: 1.0000 - val_loss: 4.2505 - val_accuracy: 0.7364 - lr: 1.0000e-04
# Epoch 41/600
# 32/32 [==============================] - 3s 92ms/step - loss: 1.3872e-06 - accuracy: 1.0000 - val_loss: 4.3663 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 42/600
# 32/32 [==============================] - 3s 103ms/step - loss: 1.0469e-06 - accuracy: 1.0000 - val_loss: 4.4510 - val_accuracy: 0.7364 - lr: 1.0000e-04
# Epoch 43/600
# 32/32 [==============================] - 3s 91ms/step - loss: 8.2389e-07 - accuracy: 1.0000 - val_loss: 4.5164 - val_accuracy: 0.7364 - lr: 1.0000e-04
# Epoch 44/600
# 32/32 [==============================] - 1011s 33s/step - loss: 6.7311e-07 - accuracy: 1.0000 - val_loss: 4.5754 - val_accuracy: 0.7364 - lr: 1.0000e-04
# Epoch 45/600
# 32/32 [==============================] - 3s 100ms/step - loss: 5.6496e-07 - accuracy: 1.0000 - val_loss: 4.6367 - val_accuracy: 0.7364 - lr: 1.0000e-04
# Epoch 46/600
# 32/32 [==============================] - ETA: 0s - loss: 4.8220e-07 - accuracy: 1.0000
# Epoch 46: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 32/32 [==============================] - 4s 113ms/step - loss: 4.8220e-07 - accuracy: 1.0000 - val_loss: 4.6899 - val_accuracy: 0.7364 - lr: 1.0000e-04
# Epoch 47/600
# 32/32 [==============================] - 4s 117ms/step - loss: 4.3368e-07 - accuracy: 1.0000 - val_loss: 4.7168 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 48/600
# 32/32 [==============================] - 3s 98ms/step - loss: 4.0460e-07 - accuracy: 1.0000 - val_loss: 4.7407 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 49/600
# 32/32 [==============================] - 3s 96ms/step - loss: 3.7801e-07 - accuracy: 1.0000 - val_loss: 4.7618 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 50/600
# 32/32 [==============================] - 3s 98ms/step - loss: 3.5549e-07 - accuracy: 1.0000 - val_loss: 4.7835 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 51/600
# 32/32 [==============================] - 3s 95ms/step - loss: 3.3436e-07 - accuracy: 1.0000 - val_loss: 4.8041 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 52/600
# 32/32 [==============================] - 3s 97ms/step - loss: 3.1546e-07 - accuracy: 1.0000 - val_loss: 4.8266 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 53/600
# 32/32 [==============================] - 3s 94ms/step - loss: 2.9815e-07 - accuracy: 1.0000 - val_loss: 4.8485 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 54/600
# 32/32 [==============================] - 3s 93ms/step - loss: 2.8043e-07 - accuracy: 1.0000 - val_loss: 4.8664 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 55/600
# 32/32 [==============================] - 3s 96ms/step - loss: 2.6627e-07 - accuracy: 1.0000 - val_loss: 4.8864 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 56/600
# 32/32 [==============================] - 3s 93ms/step - loss: 2.5192e-07 - accuracy: 1.0000 - val_loss: 4.9038 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 57/600
# 32/32 [==============================] - 3s 98ms/step - loss: 2.3920e-07 - accuracy: 1.0000 - val_loss: 4.9205 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 58/600
# 32/32 [==============================] - 3s 93ms/step - loss: 2.2831e-07 - accuracy: 1.0000 - val_loss: 4.9405 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 59/600
# 32/32 [==============================] - 3s 96ms/step - loss: 2.1625e-07 - accuracy: 1.0000 - val_loss: 4.9565 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 60/600
# 32/32 [==============================] - 3s 95ms/step - loss: 2.0608e-07 - accuracy: 1.0000 - val_loss: 4.9723 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 61/600
# 32/32 [==============================] - 3s 97ms/step - loss: 1.9730e-07 - accuracy: 1.0000 - val_loss: 4.9925 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 62/600
# 32/32 [==============================] - 3s 99ms/step - loss: 1.8736e-07 - accuracy: 1.0000 - val_loss: 5.0066 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 63/600
# 32/32 [==============================] - 3s 100ms/step - loss: 1.7968e-07 - accuracy: 1.0000 - val_loss: 5.0236 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 64/600
# 32/32 [==============================] - 3s 101ms/step - loss: 1.7151e-07 - accuracy: 1.0000 - val_loss: 5.0396 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 65/600
# 32/32 [==============================] - 3s 99ms/step - loss: 1.6402e-07 - accuracy: 1.0000 - val_loss: 5.0543 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 66/600
# 32/32 [==============================] - ETA: 0s - loss: 1.5718e-07 - accuracy: 1.0000
# Epoch 66: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 32/32 [==============================] - 3s 96ms/step - loss: 1.5718e-07 - accuracy: 1.0000 - val_loss: 5.0677 - val_accuracy: 0.7364 - lr: 5.0000e-05
# Epoch 67/600
# 32/32 [==============================] - 3s 93ms/step - loss: 1.5278e-07 - accuracy: 1.0000 - val_loss: 5.0754 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 68/600
# 32/32 [==============================] - 3s 94ms/step - loss: 1.4971e-07 - accuracy: 1.0000 - val_loss: 5.0840 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 69/600
# 32/32 [==============================] - 3s 96ms/step - loss: 1.4660e-07 - accuracy: 1.0000 - val_loss: 5.0917 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 70/600
# 32/32 [==============================] - 3s 95ms/step - loss: 1.4355e-07 - accuracy: 1.0000 - val_loss: 5.0990 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 71/600
# 32/32 [==============================] - 3s 95ms/step - loss: 1.4066e-07 - accuracy: 1.0000 - val_loss: 5.1064 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 72/600
# 32/32 [==============================] - 3s 94ms/step - loss: 1.3776e-07 - accuracy: 1.0000 - val_loss: 5.1129 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 73/600
# 32/32 [==============================] - 3s 93ms/step - loss: 1.3505e-07 - accuracy: 1.0000 - val_loss: 5.1206 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 74/600
# 32/32 [==============================] - 3s 96ms/step - loss: 1.3240e-07 - accuracy: 1.0000 - val_loss: 5.1281 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 75/600
# 32/32 [==============================] - 3s 94ms/step - loss: 1.2963e-07 - accuracy: 1.0000 - val_loss: 5.1353 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 76/600
# 32/32 [==============================] - ETA: 0s - loss: 1.2709e-07 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 26.
# 32/32 [==============================] - 3s 96ms/step - loss: 1.2709e-07 - accuracy: 1.0000 - val_loss: 5.1419 - val_accuracy: 0.7364 - lr: 2.5000e-05
# Epoch 76: early stopping

# %%
losses = pd.DataFrame(history.history)
losses.plot()
# Out:
# <Axes: >

# %%
y_pred = model.predict(x_test)
y_pred_binary = (y_pred > 0.5).astype(int)
print(classification_report(y_test,y_pred_binary))
# Out:
# 11/11 [==============================] - 1s 23ms/step
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84       242
#            1       0.55      0.30      0.39        88
#
#     accuracy                           0.75       330
#    macro avg       0.67      0.60      0.61       330
# weighted avg       0.72      0.75      0.72       330
